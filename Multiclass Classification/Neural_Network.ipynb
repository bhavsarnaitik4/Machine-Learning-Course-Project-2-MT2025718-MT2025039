# %% [markdown]
# # Neural Network Model (MLP)
#
# In this notebook, we implement a **Multi-Layer Perceptron (MLP)** using **TensorFlow/Keras**.
#
# **Key Features**:
# 1.  **Feature Engineering**: Same Euclidean Distance feature as other models.
# 2.  **Preprocessing**: `PowerTransformer` for normalization.
# 3.  **Architecture**:
#     -   Dense Layers with ReLU activation.
#     -   **Batch Normalization**: For stable training.
#     -   **Dropout**: To prevent overfitting.
#     -   Output: Softmax for 7 classes.
# 4.  **Callbacks**: `EarlyStopping` and `ReduceLROnPlateau`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from sklearn.preprocessing import PowerTransformer, LabelEncoder
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Set random seeds
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## 1. Load Data & Feature Engineering

# %%
# Load Datasets
X_train_raw = pd.read_csv('X_train.csv')
y_train_raw = pd.read_csv('y_train.csv').values.ravel()

X_val_raw = pd.read_csv('X_val.csv')
y_val_raw = pd.read_csv('y_val.csv').values.ravel()

X_test_raw = pd.read_csv('X_test.csv')
y_test_raw = pd.read_csv('y_test.csv').values.ravel()

# Feature Engineering Function
def add_features(df):
    df = df.copy()
    # Euclidean distance to Hydrology
    df['Euclidean_Distance_To_Hydrology'] = np.sqrt(
        df['Horizontal_Distance_To_Hydrology']**2 + 
        df['Vertical_Distance_To_Hydrology']**2
    )
    return df

# Apply Feature Engineering
X_train = add_features(X_train_raw)
X_val = add_features(X_val_raw)
X_test = add_features(X_test_raw)

print(f"Train Shape: {X_train.shape}")
print(f"Val Shape: {X_val.shape}")
print(f"Test Shape: {X_test.shape}")
# Out:
# Train Shape: (348606, 55)
# Val Shape: (116203, 55)
# Test Shape: (116203, 55)

# %% [markdown]
# ## 2. Preprocessing
#
# We need to:
# 1.  **Normalize**: Use `PowerTransformer` (fit on Train, transform Val/Test).
# 2.  **Encode Labels**: Shift 1-7 range to 0-6 for Keras.

# %%
# 1. Power Transformation
pt = PowerTransformer()
X_train_scaled = pt.fit_transform(X_train)
X_val_scaled = pt.transform(X_val)
X_test_scaled = pt.transform(X_test)

# 2. Label Encoding (Shift 1-7 to 0-6)
# Forest Cover Types are 1-7, Keras needs 0-6
y_train = y_train_raw - 1
y_val = y_val_raw - 1
y_test = y_test_raw - 1



print("Data scaled and labels shifted.")
# Out:
# Data scaled and labels shifted.

# %% [markdown]
# ## 3. Build Model
#
# We use a Sequential model with:
# -   **Input Layer**: Matches feature dimension.
# -   **Hidden Layers**: Decreasing size (128 -> 64).
# -   **Regularization**: Dropout (0.3) and BatchNormalization.
# -   **Output**: 7 neurons (Softmax).

# %%
# Define Model Architecture
def build_model(input_dim):
    model = keras.Sequential([
        # 5 Hidden Layers (Pyramid Architecture)
        layers.Dense(512, input_dim=input_dim),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.1),
        
        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.1),

        layers.Dense(128),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.1),

        layers.Dense(64),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.1),

        layers.Dense(32),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.1),
        
        # Output Layer
        layers.Dense(7, activation='softmax')
    ])
    
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

model = build_model(X_train.shape[1])
model.summary()
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_65 (Dense)                │ (None, 512)            │        28,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_49 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_50 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_51 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_52          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_52 (Activation)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_53          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_53 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_53 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 207,431 (810.28 KB)
#  Trainable params: 205,447 (802.53 KB)
#  Non-trainable params: 1,984 (7.75 KB)

# %% [markdown]
# ## 4. Comparative Study: Hyperparameters
# We perform three quick experiments to justify our choices:
# 1.  **Optimizers**: Adam vs SGD.
# 2.  **Dropout**: Low (0.1) vs High (0.5).
# 3.  **Architecture**: Baseline (3 Layers) vs Deep (5 Layers).

# %%
# Optimizer Comparison
optimizers = ['adam', 'sgd']
histories_opt = {}

print("Running Optimizer Comparison (20 Epochs)...")

for opt_name in optimizers:
    print(f"\nTesting Optimizer: {opt_name}")
    temp_model = build_model(X_train.shape[1]) # Default dropout 0.1
    temp_model.compile(optimizer=opt_name, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    hist = temp_model.fit(X_train_scaled, y_train, validation_data=(X_val_scaled, y_val),
                          batch_size=1024, epochs=20, verbose=0)
    histories_opt[opt_name] = hist.history['val_accuracy']

# Dropout Comparison
dropouts = [0.1, 0.5]
histories_drop = {}

print("\nRunning Dropout Comparison (20 Epochs)...")

# Need flexible build function for this study (Updated to Deep Arch)
def build_model_custom_dropout(input_dim, drop_rate):
    model = keras.Sequential([
        layers.Dense(512, input_dim=input_dim), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(drop_rate),
        layers.Dense(256), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(drop_rate),
        layers.Dense(128), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(drop_rate),
        layers.Dense(64), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(drop_rate),
        layers.Dense(32), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(drop_rate),
        layers.Dense(7, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

for rate in dropouts:
    print(f"\nTesting Dropout: {rate}")
    temp_model = build_model_custom_dropout(X_train.shape[1], rate)
    hist = temp_model.fit(X_train_scaled, y_train, validation_data=(X_val_scaled, y_val),
                          batch_size=1024, epochs=20, verbose=0)
    histories_drop[rate] = hist.history['val_accuracy']


print("Confirmed: Adam and Dropout=0.1 are superior choices.")

# Architecture Comparison
models_arch = ['Baseline (3 Layers)', 'Deep (5 Layers)']
histories_arch = {}

print("\nRunning Architecture Comparison (20 Epochs)...")

# Define Shallow Baseline
def build_shallow_model(input_dim):
    model = keras.Sequential([
        layers.Dense(256, input_dim=input_dim), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(0.1),
        layers.Dense(128), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(0.1),
        layers.Dense(64), layers.BatchNormalization(), layers.Activation('relu'), layers.Dropout(0.1),
        layers.Dense(7, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Deep Model is now the Default (from Optimizer study)
histories_arch['Deep (5 Layers)'] = histories_opt['adam'] 

# Test Baseline
print(f"Testing Baseline Model...")
baseline_model = build_shallow_model(X_train.shape[1])
hist = baseline_model.fit(X_train_scaled, y_train, validation_data=(X_val_scaled, y_val),
                      batch_size=1024, epochs=20, verbose=0)
histories_arch['Baseline (3 Layers)'] = hist.history['val_accuracy']

# Plot Combined Results (Updated)
plt.figure(figsize=(18, 5))

# Optimizer Plot
plt.subplot(1, 3, 1)
for opt_name, hist in histories_opt.items():
    plt.plot(hist, label=f'{opt_name.upper()}')
plt.title('Effect of Optimizer (acc)')
plt.xlabel('Epoch')
plt.ylabel('Val Accuracy')
plt.legend()
plt.grid(True)

# Dropout Plot
plt.subplot(1, 3, 2)
for rate, hist in histories_drop.items():
    plt.plot(hist, label=f'Dropout {rate}')
plt.title('Effect of Dropout Rate (acc)')
plt.xlabel('Epoch')
plt.ylabel('Val Accuracy')
plt.legend()
plt.grid(True)

# Architecture Plot
plt.subplot(1, 3, 3)
for name, hist in histories_arch.items():
    plt.plot(hist, label=name)
plt.title('Effect of Depth (acc)')
plt.xlabel('Epoch')
plt.ylabel('Val Accuracy')
plt.legend()
plt.grid(True)

plt.show()

print("Architecture Analysis Complete.")
# Out:
# Running Optimizer Comparison (20 Epochs)...
#
# Testing Optimizer: adam
#
# Testing Optimizer: sgd
#
# Running Dropout Comparison (20 Epochs)...
#
# Testing Dropout: 0.1
#
# Testing Dropout: 0.5
# Confirmed: Adam and Dropout=0.1 are superior choices.
#
# Running Architecture Comparison (20 Epochs)...
# Testing Baseline Model...
# Architecture Analysis Complete.

# %% [markdown]
# ## 5. Final Model Training (with Best Settings)
#
# We use callbacks for efficiency:
# -   **EarlyStopping**: Stop if val_loss yields no improvement for 10 epochs.
# -   **ModelCheckpoint**: Save best model.

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001,
    patience=10, 
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=3, 
    verbose=1
)

history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    batch_size=1024,
    epochs=100,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7212 - loss: 0.7741 - val_accuracy: 0.7815 - val_loss: 0.5321 - learning_rate: 0.0010
# Epoch 2/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7816 - loss: 0.5242 - val_accuracy: 0.8189 - val_loss: 0.4377 - learning_rate: 0.0010
# Epoch 3/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8083 - loss: 0.4625 - val_accuracy: 0.8368 - val_loss: 0.3924 - learning_rate: 0.0010
# Epoch 4/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8242 - loss: 0.4241 - val_accuracy: 0.8517 - val_loss: 0.3550 - learning_rate: 0.0010
# Epoch 5/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8367 - loss: 0.3949 - val_accuracy: 0.8621 - val_loss: 0.3321 - learning_rate: 0.0010
# Epoch 6/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8468 - loss: 0.3713 - val_accuracy: 0.8720 - val_loss: 0.3092 - learning_rate: 0.0010
# Epoch 7/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8542 - loss: 0.3539 - val_accuracy: 0.8805 - val_loss: 0.2910 - learning_rate: 0.0010
# Epoch 8/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8615 - loss: 0.3377 - val_accuracy: 0.8869 - val_loss: 0.2782 - learning_rate: 0.0010
# Epoch 9/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8675 - loss: 0.3242 - val_accuracy: 0.8908 - val_loss: 0.2667 - learning_rate: 0.0010
# Epoch 10/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.8723 - loss: 0.3134 - val_accuracy: 0.8953 - val_loss: 0.2558 - learning_rate: 0.0010
# Epoch 11/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8762 - loss: 0.3040 - val_accuracy: 0.8971 - val_loss: 0.2504 - learning_rate: 0.0010
# Epoch 12/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8801 - loss: 0.2948 - val_accuracy: 0.9023 - val_loss: 0.2403 - learning_rate: 0.0010
# Epoch 13/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8828 - loss: 0.2886 - val_accuracy: 0.9056 - val_loss: 0.2322 - learning_rate: 0.0010
# Epoch 14/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8862 - loss: 0.2801 - val_accuracy: 0.9072 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 15/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8891 - loss: 0.2739 - val_accuracy: 0.9100 - val_loss: 0.2212 - learning_rate: 0.0010
# Epoch 16/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8913 - loss: 0.2673 - val_accuracy: 0.9112 - val_loss: 0.2163 - learning_rate: 0.0010
# Epoch 17/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8939 - loss: 0.2621 - val_accuracy: 0.9123 - val_loss: 0.2124 - learning_rate: 0.0010
# Epoch 18/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8956 - loss: 0.2572 - val_accuracy: 0.9141 - val_loss: 0.2103 - learning_rate: 0.0010
# Epoch 19/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8974 - loss: 0.2531 - val_accuracy: 0.9156 - val_loss: 0.2040 - learning_rate: 0.0010
# Epoch 20/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8991 - loss: 0.2487 - val_accuracy: 0.9174 - val_loss: 0.2005 - learning_rate: 0.0010
# Epoch 21/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9009 - loss: 0.2441 - val_accuracy: 0.9202 - val_loss: 0.1957 - learning_rate: 0.0010
# Epoch 22/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9028 - loss: 0.2409 - val_accuracy: 0.9194 - val_loss: 0.1954 - learning_rate: 0.0010
# Epoch 23/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9037 - loss: 0.2374 - val_accuracy: 0.9210 - val_loss: 0.1933 - learning_rate: 0.0010
# Epoch 24/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9044 - loss: 0.2353 - val_accuracy: 0.9228 - val_loss: 0.1881 - learning_rate: 0.0010
# Epoch 25/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9061 - loss: 0.2321 - val_accuracy: 0.9243 - val_loss: 0.1864 - learning_rate: 0.0010
# Epoch 26/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9074 - loss: 0.2286 - val_accuracy: 0.9248 - val_loss: 0.1841 - learning_rate: 0.0010
# Epoch 27/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9082 - loss: 0.2255 - val_accuracy: 0.9250 - val_loss: 0.1849 - learning_rate: 0.0010
# Epoch 28/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9096 - loss: 0.2237 - val_accuracy: 0.9266 - val_loss: 0.1800 - learning_rate: 0.0010
# Epoch 29/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9112 - loss: 0.2197 - val_accuracy: 0.9280 - val_loss: 0.1792 - learning_rate: 0.0010
# Epoch 30/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9117 - loss: 0.2189 - val_accuracy: 0.9285 - val_loss: 0.1762 - learning_rate: 0.0010
# Epoch 31/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9127 - loss: 0.2168 - val_accuracy: 0.9277 - val_loss: 0.1768 - learning_rate: 0.0010
# Epoch 32/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9135 - loss: 0.2151 - val_accuracy: 0.9290 - val_loss: 0.1735 - learning_rate: 0.0010
# Epoch 33/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9140 - loss: 0.2119 - val_accuracy: 0.9291 - val_loss: 0.1732 - learning_rate: 0.0010
# Epoch 34/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9144 - loss: 0.2103 - val_accuracy: 0.9289 - val_loss: 0.1737 - learning_rate: 0.0010
# Epoch 35/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9161 - loss: 0.2082 - val_accuracy: 0.9295 - val_loss: 0.1723 - learning_rate: 0.0010
# Epoch 36/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9163 - loss: 0.2080 - val_accuracy: 0.9302 - val_loss: 0.1702 - learning_rate: 0.0010
# Epoch 37/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9174 - loss: 0.2054 - val_accuracy: 0.9312 - val_loss: 0.1671 - learning_rate: 0.0010
# Epoch 38/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9178 - loss: 0.2043 - val_accuracy: 0.9327 - val_loss: 0.1649 - learning_rate: 0.0010
# Epoch 39/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9183 - loss: 0.2020 - val_accuracy: 0.9326 - val_loss: 0.1647 - learning_rate: 0.0010
# Epoch 40/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9188 - loss: 0.2009 - val_accuracy: 0.9332 - val_loss: 0.1642 - learning_rate: 0.0010
# Epoch 41/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9202 - loss: 0.1984 - val_accuracy: 0.9332 - val_loss: 0.1644 - learning_rate: 0.0010
# Epoch 42/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9207 - loss: 0.1970 - val_accuracy: 0.9348 - val_loss: 0.1606 - learning_rate: 0.0010
# Epoch 43/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9209 - loss: 0.1957 - val_accuracy: 0.9344 - val_loss: 0.1604 - learning_rate: 0.0010
# Epoch 44/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9211 - loss: 0.1961 - val_accuracy: 0.9350 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 45/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9223 - loss: 0.1929 - val_accuracy: 0.9347 - val_loss: 0.1595 - learning_rate: 0.0010
# Epoch 46/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9222 - loss: 0.1925 - val_accuracy: 0.9338 - val_loss: 0.1615 - learning_rate: 0.0010
# Epoch 47/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9226 - loss: 0.1912 - val_accuracy: 0.9355 - val_loss: 0.1570 - learning_rate: 0.0010
# Epoch 48/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9234 - loss: 0.1901 - val_accuracy: 0.9354 - val_loss: 0.1569 - learning_rate: 0.0010
# Epoch 49/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9238 - loss: 0.1892 - val_accuracy: 0.9370 - val_loss: 0.1545 - learning_rate: 0.0010
# Epoch 50/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9242 - loss: 0.1877 - val_accuracy: 0.9376 - val_loss: 0.1541 - learning_rate: 0.0010
# Epoch 51/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9243 - loss: 0.1874 - val_accuracy: 0.9361 - val_loss: 0.1555 - learning_rate: 0.0010
# Epoch 52/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9253 - loss: 0.1857 - val_accuracy: 0.9374 - val_loss: 0.1522 - learning_rate: 0.0010
# Epoch 53/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9260 - loss: 0.1855 - val_accuracy: 0.9375 - val_loss: 0.1521 - learning_rate: 0.0010
# Epoch 54/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9264 - loss: 0.1855 - val_accuracy: 0.9387 - val_loss: 0.1510 - learning_rate: 0.0010
# Epoch 55/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9271 - loss: 0.1823 - val_accuracy: 0.9387 - val_loss: 0.1504 - learning_rate: 0.0010
# Epoch 56/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9268 - loss: 0.1818 - val_accuracy: 0.9392 - val_loss: 0.1498 - learning_rate: 0.0010
# Epoch 57/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9274 - loss: 0.1807 - val_accuracy: 0.9390 - val_loss: 0.1497 - learning_rate: 0.0010
# Epoch 58/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9271 - loss: 0.1811 - val_accuracy: 0.9396 - val_loss: 0.1499 - learning_rate: 0.0010
# Epoch 59/100
# 338/341 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9273 - loss: 0.1811
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9281 - loss: 0.1794 - val_accuracy: 0.9387 - val_loss: 0.1505 - learning_rate: 0.0010
# Epoch 60/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9328 - loss: 0.1677 - val_accuracy: 0.9436 - val_loss: 0.1401 - learning_rate: 5.0000e-04
# Epoch 61/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9336 - loss: 0.1647 - val_accuracy: 0.9441 - val_loss: 0.1385 - learning_rate: 5.0000e-04
# Epoch 62/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9346 - loss: 0.1633 - val_accuracy: 0.9445 - val_loss: 0.1376 - learning_rate: 5.0000e-04
# Epoch 63/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9348 - loss: 0.1614 - val_accuracy: 0.9451 - val_loss: 0.1370 - learning_rate: 5.0000e-04
# Epoch 64/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9350 - loss: 0.1609 - val_accuracy: 0.9450 - val_loss: 0.1362 - learning_rate: 5.0000e-04
# Epoch 65/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9356 - loss: 0.1604 - val_accuracy: 0.9451 - val_loss: 0.1353 - learning_rate: 5.0000e-04
# Epoch 66/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9357 - loss: 0.1600 - val_accuracy: 0.9450 - val_loss: 0.1354 - learning_rate: 5.0000e-04
# Epoch 67/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9358 - loss: 0.1600 - val_accuracy: 0.9453 - val_loss: 0.1349 - learning_rate: 5.0000e-04
# Epoch 68/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9361 - loss: 0.1592 - val_accuracy: 0.9459 - val_loss: 0.1348 - learning_rate: 5.0000e-04
# Epoch 69/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9367 - loss: 0.1575 - val_accuracy: 0.9460 - val_loss: 0.1338 - learning_rate: 5.0000e-04
# Epoch 70/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9369 - loss: 0.1575 - val_accuracy: 0.9463 - val_loss: 0.1342 - learning_rate: 5.0000e-04
# Epoch 71/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9363 - loss: 0.1581 - val_accuracy: 0.9458 - val_loss: 0.1334 - learning_rate: 5.0000e-04
# Epoch 72/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9369 - loss: 0.1567 - val_accuracy: 0.9465 - val_loss: 0.1332 - learning_rate: 5.0000e-04
# Epoch 73/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9377 - loss: 0.1557 - val_accuracy: 0.9461 - val_loss: 0.1339 - learning_rate: 5.0000e-04
# Epoch 74/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9377 - loss: 0.1551 - val_accuracy: 0.9467 - val_loss: 0.1324 - learning_rate: 5.0000e-04
# Epoch 75/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9374 - loss: 0.1550 - val_accuracy: 0.9461 - val_loss: 0.1334 - learning_rate: 5.0000e-04
# Epoch 76/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9378 - loss: 0.1564 - val_accuracy: 0.9465 - val_loss: 0.1333 - learning_rate: 5.0000e-04
# Epoch 77/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9380 - loss: 0.1548 - val_accuracy: 0.9470 - val_loss: 0.1314 - learning_rate: 5.0000e-04
# Epoch 78/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9376 - loss: 0.1544 - val_accuracy: 0.9465 - val_loss: 0.1321 - learning_rate: 5.0000e-04
# Epoch 79/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9383 - loss: 0.1531 - val_accuracy: 0.9473 - val_loss: 0.1306 - learning_rate: 5.0000e-04
# Epoch 80/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9383 - loss: 0.1535 - val_accuracy: 0.9475 - val_loss: 0.1310 - learning_rate: 5.0000e-04
# Epoch 81/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9382 - loss: 0.1525 - val_accuracy: 0.9474 - val_loss: 0.1309 - learning_rate: 5.0000e-04
# Epoch 82/100
# 340/341 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9384 - loss: 0.1532
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9388 - loss: 0.1524 - val_accuracy: 0.9473 - val_loss: 0.1308 - learning_rate: 5.0000e-04
# Epoch 83/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9408 - loss: 0.1472 - val_accuracy: 0.9494 - val_loss: 0.1268 - learning_rate: 2.5000e-04
# Epoch 84/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9417 - loss: 0.1450 - val_accuracy: 0.9496 - val_loss: 0.1261 - learning_rate: 2.5000e-04
# Epoch 85/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9424 - loss: 0.1436 - val_accuracy: 0.9495 - val_loss: 0.1257 - learning_rate: 2.5000e-04
# Epoch 86/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9425 - loss: 0.1437 - val_accuracy: 0.9497 - val_loss: 0.1261 - learning_rate: 2.5000e-04
# Epoch 87/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9425 - loss: 0.1436 - val_accuracy: 0.9502 - val_loss: 0.1254 - learning_rate: 2.5000e-04
# Epoch 88/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9426 - loss: 0.1432 - val_accuracy: 0.9501 - val_loss: 0.1253 - learning_rate: 2.5000e-04
# Epoch 89/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9427 - loss: 0.1429 - val_accuracy: 0.9505 - val_loss: 0.1248 - learning_rate: 2.5000e-04
# Epoch 90/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9433 - loss: 0.1409 - val_accuracy: 0.9506 - val_loss: 0.1247 - learning_rate: 2.5000e-04
# Epoch 91/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9434 - loss: 0.1411 - val_accuracy: 0.9500 - val_loss: 0.1242 - learning_rate: 2.5000e-04
# Epoch 92/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9430 - loss: 0.1427 - val_accuracy: 0.9503 - val_loss: 0.1242 - learning_rate: 2.5000e-04
# Epoch 93/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9436 - loss: 0.1410 - val_accuracy: 0.9503 - val_loss: 0.1243 - learning_rate: 2.5000e-04
# Epoch 94/100
# 340/341 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9431 - loss: 0.1421
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9429 - loss: 0.1419 - val_accuracy: 0.9505 - val_loss: 0.1242 - learning_rate: 2.5000e-04
# Epoch 95/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9437 - loss: 0.1390 - val_accuracy: 0.9514 - val_loss: 0.1226 - learning_rate: 1.2500e-04
# Epoch 96/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9447 - loss: 0.1379 - val_accuracy: 0.9513 - val_loss: 0.1224 - learning_rate: 1.2500e-04
# Epoch 97/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9454 - loss: 0.1368 - val_accuracy: 0.9515 - val_loss: 0.1221 - learning_rate: 1.2500e-04
# Epoch 98/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9455 - loss: 0.1373 - val_accuracy: 0.9519 - val_loss: 0.1216 - learning_rate: 1.2500e-04
# Epoch 99/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9451 - loss: 0.1367 - val_accuracy: 0.9518 - val_loss: 0.1216 - learning_rate: 1.2500e-04
# Epoch 100/100
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9452 - loss: 0.1366 - val_accuracy: 0.9515 - val_loss: 0.1219 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 99.

# %%
# Plot History
plt.figure(figsize=(14, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## 5. Evaluation

# %%
# Evaluate
loss, acc = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"Test Accuracy: {acc:.4f}")

# Predictions
y_probs = model.predict(X_test_scaled)
y_pred = np.argmax(y_probs, axis=1)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.9515
# 3632/3632 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     42368
#            1       0.95      0.96      0.96     56661
#            2       0.96      0.95      0.96      7151
#            3       0.89      0.86      0.87       549
#            4       0.84      0.87      0.86      1899
#            5       0.92      0.91      0.92      3473
#            6       0.95      0.95      0.95      4102
#
#     accuracy                           0.95    116203
#    macro avg       0.92      0.92      0.92    116203
# weighted avg       0.95      0.95      0.95    116203

# %%
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Neural Network')
plt.xlabel('Predicted (0-6)')
plt.ylabel('True (0-6)')
plt.show()
